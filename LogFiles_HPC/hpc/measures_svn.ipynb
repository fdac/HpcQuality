# %%
import re, json, pymongo
import gzip, sys, os, shutil, pickle, collections
from operator import itemgetter, attrgetter
from collections import Counter
import matplotlib.pyplot as plt
import numpy as np

def parse(text, name):
  size = 0
  data = {}
  data['name'] = decode(name)
  data['commits'] = []
  if text == '':
    return (0, {}, {})
  last_revision = ''
  authors = {}
  delta = 0
  files = {}
  text = text .replace('\r', '')

  cmtSize = {'2007':0, '2008':0, '2009':0, '2010':0, '2011':0,'2012':0, '2013':0, '2014':0 }
  uniqCmt  = {'2007':[], '2008':[], '2009':[] , '2010':[] , '2011':[] ,'2012':[] , '2013':[], '2014':[] }
  uniqCmtSize = {'2007':0, '2008':0, '2009':0, '2010':0, '2011':0,'2012':0, '2013':0, '2014':0 }
  authors  = {'2007':[], '2008':[], '2009':[] , '2010':[] , '2011':[] ,'2012':[] , '2013':[], '2014':[] }
  deltaYr  = {'2007':0, '2008':0, '2009':0, '2010':0, '2011':0,'2012':0, '2013':0, '2014':0 }
  totalCmt = {'2007':[], '2008':[], '2009':[] , '2010':[] , '2011':[] ,'2012':[] , '2013':[], '2014':[] }
  preyear = 0
# It's SVN

  line = text.strip().split('__NEWLINE__\n')             #get all the commits

  # get the info of each commit
  for cmt in line:
    splits = cmt.split(';')
    # There may be semicolons in the comments too
    props = splits[:7]
    year = props[3][:4]                 # get year as every list will be year driven

    revision = props[0]                                  #revision number
    valrev   = totalCmt[year]

    if revision not in valrev:                           #commit each year
       totalCmt[year].append(revision)

    author  = props[1]                                   #name of author
    valauth = authors[year]
    if author not in valauth:
       #authNum[year] += 1 
       authors[year].append(author)

    comment        = ';'.join(splits[6:])
    cmtSize[year] += len(comment)                        #comment Size
    valcmt  = uniqCmt[year]
    if comment not in valcmt:
       uniqCmt[year].append(comment)
       uniqCmtSize[year] += len(comment)                 #unique cmt size
       #uniqCmtCount[year] += 1                           #unique cmt 

    deltaYr[year] += 1

  return totalCmt, uniqCmt, authors, cmtSize, uniqCmtSize, deltaYr

# %%
  # plot the commit quality (Qc), commit/author and size/commit over time
# %matplotlib inline
def plot_trend(year_range, Qc, description):
  
  # get ready to plot
  ind = np.arange(len(year_range))
  width = 0.8


  # plot!
  plot = plt.bar(ind, Qc, width, color='b')
  plt.ylabel(description)
  plt.title(description + ' over time')
  plt.xticks(ind + width/2., year_range)
  plt.show()

# %%
def decode(text):
    return str(text).encode('string_escape')

# %%
if __name__ == '__main__':

  # Get list of files
  files = open('list_svn', 'r').readlines()
  counter = 0
  for f in files:
    f = f.strip()
    name = f
    contents = open(f).read()

    totalCmt, uniqCmt, authors, cmtSize, uniqCmtSize, deltaYr  = parse(contents, name)
    
    for key in sorted(uniqCmt.keys()):
        if len(totalCmt[key]) == 0:
           totalCmt[key].append('DivideByZeroCheck')
        if len(uniqCmt[key]) == 0:
           uniqCmt[key].append('DivideByZeroCheck')
        if len(authors[key]) == 0:
           authors[key].append('DivideByZeroCheck')
    print "\nFor file : ", name        
    print " Year   #nTC            #nUC       #Au          cmtSize    uniqCmtSize      delta"
    
    for key in sorted(uniqCmt.keys()):
        print key, ": ", len(totalCmt[key]), 
        print "          ", len(uniqCmt[key]),
        print "         ", len(authors[key]),
        print "         ", cmtSize[key], 
        print "      ", uniqCmtSize[key], 
        print "          ", deltaYr[key]
#    print "totalCmt: ", collections.OrderedDict(sorted(totalCmt.items()))
#    print "uniqCmtCount: ", collections.OrderedDict(sorted(uniqCmtCount.items()))
#    print "authNum: ", collections.OrderedDict(sorted(authNum.items()))
#    print "uniqCmtSize: ", collections.OrderedDict(sorted(uniqCmtSize.items()))
#    print "cmtSize: ", collections.OrderedDict(sorted(cmtSize.items()))
#    print "deltaYr: ", collections.OrderedDict(sorted(deltaYr.items()))


    #Qc - quality of commits, cmt_Au - commit per author, size_cmt - size per commit
    year_range = ['2008', '2009', '2010', '2011', '2012', '2013', '2014'];
    Qc = []
    cmt_Au = []
    size_cmt = []
    delta_cmt = []
    usize_ucmt = []
    print "\nFor file : ", name 
    print " Year   #Qc      uCmt/Au     size/Cmt    delta/tCmt " 
    for i in range(len(year_range)):
      key = year_range[i]
      Qc.append(float(len(uniqCmt[key]))/float(len(totalCmt[key])))
      cmt_Au.append(float(len(uniqCmt[key]))/float(len(authors[key])))
      size_cmt.append(cmtSize[key]/float(len(totalCmt[key])))
      usize_ucmt.append(uniqCmtSize[key]/float(len(uniqCmt[key])))
      delta_cmt.append(deltaYr[key]/float(len(totalCmt[key])))
      
      print  key, "  ", ("%.2f" % Qc[i]),
      print "    ", ("%.2f" % cmt_Au[i]),
      print "    ", ("%.2f" % size_cmt[i]),
      print "     ", ("%.2f" % delta_cmt[i])
   
    # Now let's plot the trends over years    
    print "\nFor file : ", name
    plot_trend(year_range, Qc, "Qc")   
    plot_trend(year_range, cmt_Au, "Cmt/Au")   
    plot_trend(year_range, size_cmt, "size/Cmt")   
    plot_trend(year_range, delta_cmt, "delta/Cmt")
# Out:
# For file :  loc.magmacl.svn
#  Year   #nTC            #nUC       #Au          cmtSize    uniqCmtSize      delta
# 2007 :  1            1           1           0        0            0
# 2008 :  1            1           1           0        0            0
# 2009 :  1            1           1           0        0            0
# 2010 :  1            1           1           0        0            0
# 2011 :  1            1           1           0        0            0
# 2012 :  294            274           5           51095        11660            1384
# 2013 :  25            24           2           9757        1223            173
# 2014 :  1            1           1           0        0            0
#
# For file :  loc.magmacl.svn
#  Year   #Qc      uCmt/Au     size/Cmt    delta/tCmt
# 2008    1.00      1.00      0.00       0.00
# 2009    1.00      1.00      0.00       0.00
# 2010    1.00      1.00      0.00       0.00
# 2011    1.00      1.00      0.00       0.00
# 2012    0.93      54.80      173.79       4.71
# 2013    0.96      12.00      390.28       6.92
# 2014    1.00      1.00      0.00       0.00
#
# For file :  loc.magmacl.svn
# For file :  loc.magmamicl.svn
#  Year   #nTC            #nUC       #Au          cmtSize    uniqCmtSize      delta
# 2007 :  1            1           1           0        0            0
# 2008 :  1            1           1           0        0            0
# 2009 :  1            1           1           0        0            0
# 2010 :  1            1           1           0        0            0
# 2011 :  1            1           1           0        0            0
# 2012 :  1            1           1           0        0            0
# 2013 :  223            204           6           33395        6910            891
# 2014 :  45            45           3           30082        2129            583
#
# For file :  loc.magmamicl.svn
#  Year   #Qc      uCmt/Au     size/Cmt    delta/tCmt
# 2008    1.00      1.00      0.00       0.00
# 2009    1.00      1.00      0.00       0.00
# 2010    1.00      1.00      0.00       0.00
# 2011    1.00      1.00      0.00       0.00
# 2012    1.00      1.00      0.00       0.00
# 2013    0.91      34.00      149.75       4.00
# 2014    1.00      15.00      668.49       12.96
#
# For file :  loc.magmamicl.svn
# For file :  loc.magma.svn
#  Year   #nTC            #nUC       #Au          cmtSize    uniqCmtSize      delta
# 2007 :  1            1           1           0        0            0
# 2008 :  1            1           1           0        0            0
# 2009 :  149            144           5           56877        8604            877
# 2010 :  643            623           9           182708        57377            2275
# 2011 :  517            491           8           160526        30854            2788
# 2012 :  810            738           12           197405        37198            3201
# 2013 :  894            829           9           183514        38586            3607
# 2014 :  1135            1018           9           321781        37683            5803
#
# For file :  loc.magma.svn
#  Year   #Qc      uCmt/Au     size/Cmt    delta/tCmt
# 2008    1.00      1.00      0.00       0.00
# 2009    0.97      28.80      381.72       5.89
# 2010    0.97      69.22      284.15       3.54
# 2011    0.95      61.38      310.50       5.39
# 2012    0.91      61.50      243.71       3.95
# 2013    0.93      92.11      205.27       4.03
# 2014    0.90      113.11      283.51       5.11
#
# For file :  loc.magma.svn
# For file :  loc.plasma.svn
#  Year   #nTC            #nUC       #Au          cmtSize    uniqCmtSize      delta
# 2007 :  1            1           1           0        0            0
# 2008 :  176            165           4           39403        7456            1155
# 2009 :  808            761           10           700003        71115            6664
# 2010 :  894            865           11           860337        75633            8318
# 2011 :  998            961           11           924931        60183            13527
# 2012 :  483            450           11           420869        26524            6795
# 2013 :  404            379           9           380306        20108            6653
# 2014 :  236            224           4           73209        13365            1067
#
# For file :  loc.plasma.svn
#  Year   #Qc      uCmt/Au     size/Cmt    delta/tCmt
# 2008    0.94      41.25      223.88       6.56
# 2009    0.94      76.10      866.34       8.25
# 2010    0.97      78.64      962.35       9.30
# 2011    0.96      87.36      926.78       13.55
# 2012    0.93      40.91      871.36       14.07
# 2013    0.94      42.11      941.35       16.47
# 2014    0.95      56.00      310.21       4.52
#
# For file :  loc.plasma.svn
