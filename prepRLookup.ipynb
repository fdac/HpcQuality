# %%
#Read prepR.r
prepR <- read.table("prepR.r",sep=';', header=T)
head(prepR)
# Out:
#                                 repo nW nFr nPu   nDe nAu  nFi vcs     Siz
# 1        000000brodie_public-testing  1   0   0     0   0    0  hg     551
# 2 000paradox000_master-details-final  1   0   0    51   1   51 git  545924
# 3            000technofreak_training  1   0   0   216   1  189 git 1157969
# 4                        0022_mohsen  0   0   0 11503   3 5994  hg    1419
# 5                  0077cc_deploytest  1   0   0     0   0    0 git     580
# 6   0077cc_practical-django-projects  1   0   0   426   1  378  hg  590776
#         from         to              u nFl nFd
# 1 1321070636 1344486180   000000brodie   0   0
# 2 1385693899 1385709741  000paradox000   0   0
# 3 1404394329 1409842731 000technofreak   0   0
# 4 1309955660 1340680250           0022   0   0
# 5 1374481548 1374481549         0077cc   0   0
# 6 1353192760 1353192760         0077cc   0   0

# %%
#Read list_all
hpc_repo <- read.table("list_all",sep=' ',header=F,comment.char="",quote="")
names(hpc_repo) <- c("repoName")
hpc_repo$repoName <- gsub("/", "_", hpc_repo$repoName)
hpc_repo

#Find the repos in prepR.r
rows <- c(match(hpc_repo$repoName,prepR$repo))
allkeywords <- prepR[rows,]
allkeywords
# Out:
#                                                           repoName
# 1                                               blkwolf_hpc-puppet
# 2                                                DavidSichau_miind
# 3                                                     sobek44_mlcc
# 4                                                    petermr_pluto
# 5                                                      mcek_kaichu
# 6                                                         rhc_pmix
# 7                                                      jkyle_galra
# 8                                            mkrautz_mumble-mirror
# 9                                                 ben_albrecht_qcl
# 10                                                   so61pi_matrix
# 11                                             Mojusko_biglearning
# 12                                              radimklaska_apikey
# 13                                                gaijiading_lobre
# 14                                       nye_qmake-openmpi-feature
# 15                           alexandrecostapb_restricted-space-knn
# 16                                           naviserver_naviserver
# 17                                    gik0geck0_gpugraphalgorithms
# 18                                                dynamicguy_disco
# 19                                rsachetto_simplenumericallibrary
# 20                                          JPereda_multimodel3dfx
# 21                                                         _pol_yt
# 22                                        Yurlungur_cython-example
# 23                                                 dekozo_pyslinky
# 24                                  natefoo_sputnik-mononucleotide
# 25                                                weberc2_spamfilt
# 26                                         ddinh_plasma-benchmarks
# 27                                               mari_yamasaki_hw7
# 28                                      hammerstad_it3105-pokerbot
# 29                                           helhound_miner-config
# 30                              pguptapict_ec2-provisioning-engine
# 31                rakvium_slobodastudio-rails-vagrant-test-rakvium
# 32                                         h2_energy-visualization
# 33                                           codedivine_maxflopscl
# 34                        tempredirect_groovyalgorithmsinanutshell
# 35                                    belenbaas_sensorlatencytable
# 36       vallenovasac_org.idempiere.vallenova.registromasivoseries
# 37                                         galtay_enzo-3.0-scaling
# 38                                             kasterma_clustering
# 39                                     martinjvickers_k-means-cuda
# 40                                        mdye_api_runtime_compare
# 41                                           nmaekawa_vmware_tools
# 42                                        allenLao_linear_transfer
# 43                   wpalchemist_chamber-dashboard-events-calendar
# 44                                                 minhix_project3
# 45                                    timurbazhirov_espresso-4.0.3
# 46                                            svmwebdev_vmdevviper
# 47                                                    gugahoi_blur
# 48                           lance_parsons_cutadapt_galaxy_wrapper
# 49                                               iljaas_sac-iljaas
# 50                                         rlangolf_compass-magick
# 51                                                xredor_wrf2grads
# 52                                                       wresch_st
# 53                                               hseara_g_h_trj_cm
# 54                                uncreative_geoprofiles_neighbors
# 55                                              alexandrul_dulwich
# 56                                     Diego_Caridei_intent-part-1
# 57                                              hr_s_octavewrapper
# 58                                     joshua.adelman_chambertools
# 59                                           py_project_vasphelper
# 60                                               mshoaazar_swf-sge
# 61                                  cml_dictionary-compchem-nwchem
# 62                                           larsyencken_jp-places
# 63                                                dayalsoap_lammps
# 64                                 stray_train_version-control-fun
# 65                                                     bjvca_pasic
# 66                                                    mapdes_petsc
# 67                               ratkins_technocolourdreamcoat2014
# 68                                                     sboz_wendel
# 69 joachimjacob_galaxy-central-fixing-discordant-reporting-tophat2
# 70                            ua-uits-solarch_ac-koa-hipchat-lenny
# 71                                            Dreampursue_samtools
# 72                                 infinit-group_instatain_android
# 73                                      pixelmerge_pixelmerge-docs
# 74                                cml_dictionary-compchem-gaussian
# 75                                        christophert_csap-stacks
# 76                                   abda11ah_opencart-payplug-mod
# 77                                   hexarobi_ac-koa-hipchat-sassy
# 78                                              jw-team_newsmaker2
# 79                                  stephanalber_phonegap-applinks
# 80                                                     nampi_2task
# 81                                               ralfoide_nerdkill
# 82                                        mooviefish_fftw3_android
# 83                                            zetdata_dataexplorer
# 84                                     iannis_b_scc-netcdf-checker
# 85                                       thunderhead-com_jgit-flow
# 86                                      chemoelectric_pure-lapacke
# 87                            kryptick_tk-jbd-submit-mayaplayblast
# 88                                           psitomcat_mythen2hdf5
# 89                       robertmassaioli_atlassian-connect-haskell
#                                                                   repo nW nFr
# 48615                                               blkwolf_hpc-puppet  1   0
# 87965                                                DavidSichau_miind  1   0
# NA                                                                <NA> NA  NA
# 286841                                                   petermr_pluto  2   0
# 236048                                                     mcek_kaichu  1   0
# 310552                                                        rhc_pmix  1   0
# 179091                                                     jkyle_galra  1   0
# 247000                                           mkrautz_mumble-mirror  2   0
# 42763                                                 ben_albrecht_qcl  1   0
# NA.1                                                              <NA> NA  NA
# 249322                                             Mojusko_biglearning  1   0
# 302123                                              radimklaska_apikey  1   0
# 131307                                                gaijiading_lobre  1   0
# 273005                                       nye_qmake-openmpi-feature  1   0
# 15401                            alexandrecostapb_restricted-space-knn  1   0
# 261688                                           naviserver_naviserver 13   5
# NA.2                                                              <NA> NA  NA
# 107178                                                dynamicguy_disco  1   0
# NA.3                                                              <NA> NA  NA
# NA.4                                                              <NA> NA  NA
# 292709                                                         _pol_yt  1   0
# NA.5                                                              <NA> NA  NA
# 91351                                                  dekozo_pyslinky  1   0
# 261139                                  natefoo_sputnik-mononucleotide  1   0
# NA.6                                                              <NA> NA  NA
# NA.7                                                              <NA> NA  NA
# 229378                                               mari_yamasaki_hw7  1   0
# 146636                                      hammerstad_it3105-pokerbot  1   0
# 149683                                           helhound_miner-config  1   0
# 287630                              pguptapict_ec2-provisioning-engine  1   0
# NA.8                                                              <NA> NA  NA
# NA.9                                                              <NA> NA  NA
# 72829                                            codedivine_maxflopscl  1   0
# NA.10                                                             <NA> NA  NA
# 42549                                     belenbaas_sensorlatencytable  1   0
# NA.11                                                             <NA> NA  NA
# 131594                                         galtay_enzo-3.0-scaling  1   0
# NA.12                                                             <NA> NA  NA
# 230897                                     martinjvickers_k-means-cuda  1   0
# 237154                                        mdye_api_runtime_compare  2   0
# 268983                                           nmaekawa_vmware_tools  1   0
# 17814                                         allenLao_linear_transfer  1   0
# NA.13                                                             <NA> NA  NA
# 244335                                                 minhix_project3  1   0
# 369814                                    timurbazhirov_espresso-4.0.3  1   0
# 356527                                            svmwebdev_vmdevviper  2   0
# 143882                                                    gugahoi_blur  1   0
# 209535                           lance_parsons_cutadapt_galaxy_wrapper  2   0
# 159402                                               iljaas_sac-iljaas  1   0
# NA.14                                                             <NA> NA  NA
# 404996                                                xredor_wrf2grads  1   0
# 401115                                                       wresch_st  1   0
# 154215                                               hseara_g_h_trj_cm  1   0
# 382874                                uncreative_geoprofiles_neighbors  2   0
# 15473                                               alexandrul_dulwich  1   0
# NA.15                                                             <NA> NA  NA
# 154138                                              hr_s_octavewrapper  1   0
# 185699                                     joshua.adelman_chambertools  1   0
# 299511                                           py_project_vasphelper  1   0
# 253692                                               mshoaazar_swf-sge  1   0
# 71880                                   cml_dictionary-compchem-nwchem  1   0
# 210115                                           larsyencken_jp-places  2   0
# NA.16                                                             <NA> NA  NA
# 353164                                 stray_train_version-control-fun  1   0
# 47479                                                      bjvca_pasic  1   0
# NA.17                                                             <NA> NA  NA
# NA.18                                                             <NA> NA  NA
# 327629                                                     sboz_wendel  7   0
# 180850 joachimjacob_galaxy-central-fixing-discordant-reporting-tophat2  1   0
# NA.19                                                             <NA> NA  NA
# 103343                                            Dreampursue_samtools  1   0
# 161046                                 infinit-group_instatain_android  1   0
# 290285                                      pixelmerge_pixelmerge-docs  2   0
# 71879                                 cml_dictionary-compchem-gaussian  1   0
# 68410                                         christophert_csap-stacks  1   0
# 4080                                     abda11ah_opencart-payplug-mod  1   0
# NA.20                                                             <NA> NA  NA
# 191110                                              jw-team_newsmaker2  2   0
# 351416                                  stephanalber_phonegap-applinks  1   0
# 260117                                                     nampi_2task  1   0
# NA.21                                                             <NA> NA  NA
# 250191                                        mooviefish_fftw3_android  1   0
# NA.22                                                             <NA> NA  NA
# NA.23                                                             <NA> NA  NA
# NA.24                                                             <NA> NA  NA
# 65961                                       chemoelectric_pure-lapacke  1   0
# 206033                            kryptick_tk-jbd-submit-mayaplayblast  1   0
# 297490                                           psitomcat_mythen2hdf5  2   0
# 314588                       robertmassaioli_atlassian-connect-haskell  1   0
#        nPu   nDe nAu   nFi  vcs       Siz       from         to
# 48615    0   309   1   202  git    224119 1351712852 1354571546
# 87965    0  3231   1  1462  git   4087908 1335533736 1345856400
# NA      NA    NA  NA    NA <NA>        NA         NA         NA
# 286841   0     0   0     0   hg     12732 1394827446 1394829286
# 236048   0   125   3    56  git    209877 1346779147 1371090892
# 310552   0   191   1   127   hg    409385 1386448027 1386922013
# 179091   0   118   2    59  git    503518 1393046813 1405051038
# 247000   0  6804   8   661   hg   7205988 1219448956 1340578111
# 42763    0    13   1    12  git    185482 1399694321 1410474287
# NA.1    NA    NA  NA    NA <NA>        NA         NA         NA
# 249322   0   112   1    80  git 700878975 1407526985 1411443396
# 302123   0     2   1     2  git     66925 1393365465 1393366201
# 131307   0    12   1    11  git   1388119 1410479539 1411852292
# 273005   0     3   1     2  git     58559 1398390539 1398390866
# 15401    0   149   1   148  git  11032014 1411769590 1411774773
# 261688   2 13607  33  2201   hg  11879372 1227000334 1411925214
# NA.2    NA    NA  NA    NA <NA>        NA         NA         NA
# 107178   0  5833  46   884  git  10380108 1405734166 1405734166
# NA.3    NA    NA  NA    NA <NA>        NA         NA         NA
# NA.4    NA    NA  NA    NA <NA>        NA         NA         NA
# 292709   0 23603  54  2036   hg  45392639 1374709662 1374709662
# NA.5    NA    NA  NA    NA <NA>        NA         NA         NA
# 91351    0    27   1    10  git    410481 1411074523 1411074523
# 261139   0     4   1     4   hg      1956 1286330351 1340708806
# NA.6    NA    NA  NA    NA <NA>        NA         NA         NA
# NA.7    NA    NA  NA    NA <NA>        NA         NA         NA
# 229378   0    20   1    20  git  30389530 1406279258 1406283081
# 146636   0    26   1    26  git    207644 1404881849 1404881849
# 149683   0     1   1     1  git     46867 1410323512 1410323512
# 287630   0     1   1     1  git   1825119 1401147665 1401147945
# NA.8    NA    NA  NA    NA <NA>        NA         NA         NA
# NA.9    NA    NA  NA    NA <NA>        NA         NA         NA
# 72829    0    12   2     3   hg     34602 1369646894 1394453429
# NA.10   NA    NA  NA    NA <NA>        NA         NA         NA
# 42549    0    18   1    14   hg     90474 1380690770 1380690825
# NA.11   NA    NA  NA    NA <NA>        NA         NA         NA
# 131594   0 47641  68  5966   hg  75265238 1404359866 1404378300
# NA.12   NA    NA  NA    NA <NA>        NA         NA         NA
# 230897   0     4   2     2  git    101536 1406470569 1406488221
# 237154   0    80   3    49  git   1574749 1404478015 1405036784
# 268983   0     0   0     0  git  60016139 1392426031 1392426280
# 17814    0    22   1    19  git  17707585 1409575005 1409575550
# NA.13   NA    NA  NA    NA <NA>        NA         NA         NA
# 244335   0   151   3   124  git  85807338 1411561061 1411928655
# 369814   0  4843   2  4843  git  44483891 1405669733 1405669733
# 356527   0   228   1   228   hg   2855728 1386215370 1386218017
# 143882   0     1   1     1  git     62311 1410733025 1410733138
# 209535   0    38   1    14   hg     53369 1411088961 1411507344
# 159402   0     0   0     0  git     33348 1389720800 1389720800
# NA.14   NA    NA  NA    NA <NA>        NA         NA         NA
# 404996   0    27   1    25   hg     78570 1380138737 1380138947
# 401115   0     0   0     0  git     33348 1399674247 1399674247
# 154215   0     2   1     2  git      8276 1371998039 1372018955
# 382874   0    12   1     9  git    404735 1325325309 1343125983
# 15473    0  7288  83   410   hg   4735928 1397323290 1397323736
# NA.15   NA    NA  NA    NA <NA>        NA         NA         NA
# 154138   0     0   0     0  git     33348 1410144784 1410144815
# 185699   0     7   1     6   hg      8164 1357874077 1358290012
# 299511   0 11317   1 11317   hg  12350579 1271064666 1340683589
# 253692   0    15   1    13  git    270325 1391481141 1391634346
# 71880    0     3   3     1   hg      6519 1329709061 1329838327
# 210115   0    16   2    12   hg     22709 1239294087 1347366595
# NA.16   NA    NA  NA    NA <NA>        NA         NA         NA
# 353164   0    21   1    17   hg     14492 1374712481 1374713172
# 47479    0    66   3    30  git   2604313 1411643768 1411667744
# NA.17   NA    NA  NA    NA <NA>        NA         NA         NA
# NA.18   NA    NA  NA    NA <NA>        NA         NA         NA
# 327629   0  8529   1  4310   hg  58026467 1312686263 1365512968
# 180850   0 38462  75  6882   hg 141647512 1360675993 1360677355
# NA.19   NA    NA  NA    NA <NA>        NA         NA         NA
# 103343   0  2026  11   191  git   4842395 1393866103 1393866104
# 161046   0     0   0     0  git       697 1369838946 1371777452
# 290285   0    44   1    30  git     28930 1345414423 1346432366
# 71879    0     2   2     1   hg     11964 1329709022 1329742675
# 68410    0    26   1    16  git    314415 1395946041 1395954941
# 4080     0    59   3    15  git    946812 1406134388 1410788748
# NA.20   NA    NA  NA    NA <NA>        NA         NA         NA
# 191110   0    36   2    20  git   5794086 1409333911 1410436411
# 351416   0     7   1     4  git    121489 1408755178 1408761980
# 260117   0     0   0     0  git     33348 1385430591 1385430591
# NA.21   NA    NA  NA    NA <NA>        NA         NA         NA
# 250191   0    14   1    14  git   1908759 1404734140 1404734140
# NA.22   NA    NA  NA    NA <NA>        NA         NA         NA
# NA.23   NA    NA  NA    NA <NA>        NA         NA         NA
# NA.24   NA    NA  NA    NA <NA>        NA         NA         NA
# 65961    0     9   1     5   hg      6264 1316516818 1343278672
# 206033   0    20   2    16  git    209410 1409590626 1409590626
# 297490   0     2   1     2  git     63144 1410369914 1410369994
# 314588   0    78   3    30  git    889521 1407141634 1410434711
#                       u nFl nFd
# 48615           blkwolf   0   0
# 87965       DavidSichau   1   0
# NA                 <NA>  NA  NA
# 286841          petermr  25   0
# 236048             mcek   1   0
# 310552              rhc   8   1
# 179091            jkyle   0   3
# 247000          mkrautz   2   0
# 42763      ben_albrecht   0   3
# NA.1               <NA>  NA  NA
# 249322          Mojusko   0   0
# 302123      radimklaska   5  14
# 131307       gaijiading   1   3
# 273005              nye   0   3
# 15401  alexandrecostapb   0   0
# 261688       naviserver  10   1
# NA.2               <NA>  NA  NA
# 107178       dynamicguy   0   0
# NA.3               <NA>  NA  NA
# NA.4               <NA>  NA  NA
# 292709             _pol   0   1
# NA.5               <NA>  NA  NA
# 91351            dekozo   1   1
# 261139          natefoo   6   0
# NA.6               <NA>  NA  NA
# NA.7               <NA>  NA  NA
# 229378    mari_yamasaki   0   0
# 146636       hammerstad   0   0
# 149683         helhound   5   3
# 287630       pguptapict   0   0
# NA.8               <NA>  NA  NA
# NA.9               <NA>  NA  NA
# 72829        codedivine   0   0
# NA.10              <NA>  NA  NA
# 42549         belenbaas   0   0
# NA.11              <NA>  NA  NA
# 131594           galtay   0   1
# NA.12              <NA>  NA  NA
# 230897   martinjvickers   0   0
# 237154             mdye   1   4
# 268983         nmaekawa   3   0
# 17814          allenLao   0   0
# NA.13              <NA>  NA  NA
# 244335           minhix   0   0
# 369814    timurbazhirov   0   0
# 356527        svmwebdev   3   0
# 143882          gugahoi   0   0
# 209535    lance_parsons   2   9
# 159402           iljaas   0   0
# NA.14              <NA>  NA  NA
# 404996           xredor   1   2
# 401115           wresch   0   0
# 154215           hseara   0   1
# 382874       uncreative   0   0
# 15473        alexandrul   3   0
# NA.15              <NA>  NA  NA
# 154138             hr_s   0   0
# 185699   joshua.adelman   3  15
# 299511       py_project   0   0
# 253692        mshoaazar   1   0
# 71880               cml   4   0
# 210115      larsyencken  10  13
# NA.16              <NA>  NA  NA
# 353164      stray_train   0   0
# 47479             bjvca   0   0
# NA.17              <NA>  NA  NA
# NA.18              <NA>  NA  NA
# 327629             sboz   1   0
# 180850     joachimjacob   0   0
# NA.19              <NA>  NA  NA
# 103343      Dreampursue   1   1
# 161046    infinit-group   1   0
# 290285       pixelmerge   0   0
# 71879               cml   4   0
# 68410      christophert   0   0
# 4080           abda11ah   0   0
# NA.20              <NA>  NA  NA
# 191110          jw-team   0   0
# 351416     stephanalber   0   0
# 260117            nampi   0   0
# NA.21              <NA>  NA  NA
# 250191       mooviefish   0   0
# NA.22              <NA>  NA  NA
# NA.23              <NA>  NA  NA
# NA.24              <NA>  NA  NA
# 65961     chemoelectric   3   6
# 206033         kryptick   0   0
# 297490        psitomcat   4   0
# 314588  robertmassaioli   8   4

# %%
row_to_keep <- which(allkeywords$repo != "<NA>")

length(row_to_keep)
allkeywords <- allkeywords[row_to_keep,]
allkeywords
# Out:
# [1] 64
#                                                                   repo nW nFr
# 48615                                               blkwolf_hpc-puppet  1   0
# 87965                                                DavidSichau_miind  1   0
# 286841                                                   petermr_pluto  2   0
# 236048                                                     mcek_kaichu  1   0
# 310552                                                        rhc_pmix  1   0
# 179091                                                     jkyle_galra  1   0
# 247000                                           mkrautz_mumble-mirror  2   0
# 42763                                                 ben_albrecht_qcl  1   0
# 249322                                             Mojusko_biglearning  1   0
# 302123                                              radimklaska_apikey  1   0
# 131307                                                gaijiading_lobre  1   0
# 273005                                       nye_qmake-openmpi-feature  1   0
# 15401                            alexandrecostapb_restricted-space-knn  1   0
# 261688                                           naviserver_naviserver 13   5
# 107178                                                dynamicguy_disco  1   0
# 292709                                                         _pol_yt  1   0
# 91351                                                  dekozo_pyslinky  1   0
# 261139                                  natefoo_sputnik-mononucleotide  1   0
# 229378                                               mari_yamasaki_hw7  1   0
# 146636                                      hammerstad_it3105-pokerbot  1   0
# 149683                                           helhound_miner-config  1   0
# 287630                              pguptapict_ec2-provisioning-engine  1   0
# 72829                                            codedivine_maxflopscl  1   0
# 42549                                     belenbaas_sensorlatencytable  1   0
# 131594                                         galtay_enzo-3.0-scaling  1   0
# 230897                                     martinjvickers_k-means-cuda  1   0
# 237154                                        mdye_api_runtime_compare  2   0
# 268983                                           nmaekawa_vmware_tools  1   0
# 17814                                         allenLao_linear_transfer  1   0
# 244335                                                 minhix_project3  1   0
# 369814                                    timurbazhirov_espresso-4.0.3  1   0
# 356527                                            svmwebdev_vmdevviper  2   0
# 143882                                                    gugahoi_blur  1   0
# 209535                           lance_parsons_cutadapt_galaxy_wrapper  2   0
# 159402                                               iljaas_sac-iljaas  1   0
# 404996                                                xredor_wrf2grads  1   0
# 401115                                                       wresch_st  1   0
# 154215                                               hseara_g_h_trj_cm  1   0
# 382874                                uncreative_geoprofiles_neighbors  2   0
# 15473                                               alexandrul_dulwich  1   0
# 154138                                              hr_s_octavewrapper  1   0
# 185699                                     joshua.adelman_chambertools  1   0
# 299511                                           py_project_vasphelper  1   0
# 253692                                               mshoaazar_swf-sge  1   0
# 71880                                   cml_dictionary-compchem-nwchem  1   0
# 210115                                           larsyencken_jp-places  2   0
# 353164                                 stray_train_version-control-fun  1   0
# 47479                                                      bjvca_pasic  1   0
# 327629                                                     sboz_wendel  7   0
# 180850 joachimjacob_galaxy-central-fixing-discordant-reporting-tophat2  1   0
# 103343                                            Dreampursue_samtools  1   0
# 161046                                 infinit-group_instatain_android  1   0
# 290285                                      pixelmerge_pixelmerge-docs  2   0
# 71879                                 cml_dictionary-compchem-gaussian  1   0
# 68410                                         christophert_csap-stacks  1   0
# 4080                                     abda11ah_opencart-payplug-mod  1   0
# 191110                                              jw-team_newsmaker2  2   0
# 351416                                  stephanalber_phonegap-applinks  1   0
# 260117                                                     nampi_2task  1   0
# 250191                                        mooviefish_fftw3_android  1   0
# 65961                                       chemoelectric_pure-lapacke  1   0
# 206033                            kryptick_tk-jbd-submit-mayaplayblast  1   0
# 297490                                           psitomcat_mythen2hdf5  2   0
# 314588                       robertmassaioli_atlassian-connect-haskell  1   0
#        nPu   nDe nAu   nFi vcs       Siz       from         to                u
# 48615    0   309   1   202 git    224119 1351712852 1354571546          blkwolf
# 87965    0  3231   1  1462 git   4087908 1335533736 1345856400      DavidSichau
# 286841   0     0   0     0  hg     12732 1394827446 1394829286          petermr
# 236048   0   125   3    56 git    209877 1346779147 1371090892             mcek
# 310552   0   191   1   127  hg    409385 1386448027 1386922013              rhc
# 179091   0   118   2    59 git    503518 1393046813 1405051038            jkyle
# 247000   0  6804   8   661  hg   7205988 1219448956 1340578111          mkrautz
# 42763    0    13   1    12 git    185482 1399694321 1410474287     ben_albrecht
# 249322   0   112   1    80 git 700878975 1407526985 1411443396          Mojusko
# 302123   0     2   1     2 git     66925 1393365465 1393366201      radimklaska
# 131307   0    12   1    11 git   1388119 1410479539 1411852292       gaijiading
# 273005   0     3   1     2 git     58559 1398390539 1398390866              nye
# 15401    0   149   1   148 git  11032014 1411769590 1411774773 alexandrecostapb
# 261688   2 13607  33  2201  hg  11879372 1227000334 1411925214       naviserver
# 107178   0  5833  46   884 git  10380108 1405734166 1405734166       dynamicguy
# 292709   0 23603  54  2036  hg  45392639 1374709662 1374709662             _pol
# 91351    0    27   1    10 git    410481 1411074523 1411074523           dekozo
# 261139   0     4   1     4  hg      1956 1286330351 1340708806          natefoo
# 229378   0    20   1    20 git  30389530 1406279258 1406283081    mari_yamasaki
# 146636   0    26   1    26 git    207644 1404881849 1404881849       hammerstad
# 149683   0     1   1     1 git     46867 1410323512 1410323512         helhound
# 287630   0     1   1     1 git   1825119 1401147665 1401147945       pguptapict
# 72829    0    12   2     3  hg     34602 1369646894 1394453429       codedivine
# 42549    0    18   1    14  hg     90474 1380690770 1380690825        belenbaas
# 131594   0 47641  68  5966  hg  75265238 1404359866 1404378300           galtay
# 230897   0     4   2     2 git    101536 1406470569 1406488221   martinjvickers
# 237154   0    80   3    49 git   1574749 1404478015 1405036784             mdye
# 268983   0     0   0     0 git  60016139 1392426031 1392426280         nmaekawa
# 17814    0    22   1    19 git  17707585 1409575005 1409575550         allenLao
# 244335   0   151   3   124 git  85807338 1411561061 1411928655           minhix
# 369814   0  4843   2  4843 git  44483891 1405669733 1405669733    timurbazhirov
# 356527   0   228   1   228  hg   2855728 1386215370 1386218017        svmwebdev
# 143882   0     1   1     1 git     62311 1410733025 1410733138          gugahoi
# 209535   0    38   1    14  hg     53369 1411088961 1411507344    lance_parsons
# 159402   0     0   0     0 git     33348 1389720800 1389720800           iljaas
# 404996   0    27   1    25  hg     78570 1380138737 1380138947           xredor
# 401115   0     0   0     0 git     33348 1399674247 1399674247           wresch
# 154215   0     2   1     2 git      8276 1371998039 1372018955           hseara
# 382874   0    12   1     9 git    404735 1325325309 1343125983       uncreative
# 15473    0  7288  83   410  hg   4735928 1397323290 1397323736       alexandrul
# 154138   0     0   0     0 git     33348 1410144784 1410144815             hr_s
# 185699   0     7   1     6  hg      8164 1357874077 1358290012   joshua.adelman
# 299511   0 11317   1 11317  hg  12350579 1271064666 1340683589       py_project
# 253692   0    15   1    13 git    270325 1391481141 1391634346        mshoaazar
# 71880    0     3   3     1  hg      6519 1329709061 1329838327              cml
# 210115   0    16   2    12  hg     22709 1239294087 1347366595      larsyencken
# 353164   0    21   1    17  hg     14492 1374712481 1374713172      stray_train
# 47479    0    66   3    30 git   2604313 1411643768 1411667744            bjvca
# 327629   0  8529   1  4310  hg  58026467 1312686263 1365512968             sboz
# 180850   0 38462  75  6882  hg 141647512 1360675993 1360677355     joachimjacob
# 103343   0  2026  11   191 git   4842395 1393866103 1393866104      Dreampursue
# 161046   0     0   0     0 git       697 1369838946 1371777452    infinit-group
# 290285   0    44   1    30 git     28930 1345414423 1346432366       pixelmerge
# 71879    0     2   2     1  hg     11964 1329709022 1329742675              cml
# 68410    0    26   1    16 git    314415 1395946041 1395954941     christophert
# 4080     0    59   3    15 git    946812 1406134388 1410788748         abda11ah
# 191110   0    36   2    20 git   5794086 1409333911 1410436411          jw-team
# 351416   0     7   1     4 git    121489 1408755178 1408761980     stephanalber
# 260117   0     0   0     0 git     33348 1385430591 1385430591            nampi
# 250191   0    14   1    14 git   1908759 1404734140 1404734140       mooviefish
# 65961    0     9   1     5  hg      6264 1316516818 1343278672    chemoelectric
# 206033   0    20   2    16 git    209410 1409590626 1409590626         kryptick
# 297490   0     2   1     2 git     63144 1410369914 1410369994        psitomcat
# 314588   0    78   3    30 git    889521 1407141634 1410434711  robertmassaioli
#        nFl nFd
# 48615    0   0
# 87965    1   0
# 286841  25   0
# 236048   1   0
# 310552   8   1
# 179091   0   3
# 247000   2   0
# 42763    0   3
# 249322   0   0
# 302123   5  14
# 131307   1   3
# 273005   0   3
# 15401    0   0
# 261688  10   1
# 107178   0   0
# 292709   0   1
# 91351    1   1
# 261139   6   0
# 229378   0   0
# 146636   0   0
# 149683   5   3
# 287630   0   0
# 72829    0   0
# 42549    0   0
# 131594   0   1
# 230897   0   0
# 237154   1   4
# 268983   3   0
# 17814    0   0
# 244335   0   0
# 369814   0   0
# 356527   3   0
# 143882   0   0
# 209535   2   9
# 159402   0   0
# 404996   1   2
# 401115   0   0
# 154215   0   1
# 382874   0   0
# 15473    3   0
# 154138   0   0
# 185699   3  15
# 299511   0   0
# 253692   1   0
# 71880    4   0
# 210115  10  13
# 353164   0   0
# 47479    0   0
# 327629   1   0
# 180850   0   0
# 103343   1   1
# 161046   1   0
# 290285   0   0
# 71879    4   0
# 68410    0   0
# 4080     0   0
# 191110   0   0
# 351416   0   0
# 260117   0   0
# 250191   0   0
# 65961    3   6
# 206033   0   0
# 297490   4   0
# 314588   8   4

# %%
#read list_keywords
hpc_repo <- read.table("list_keywords",sep=' ',header=F,comment.char="",quote="")
names(hpc_repo) <- c("key","c", "repoName")
hpc_repo

rows <- c(match(hpc_repo$repoName,prepR$repo))
keywords <- prepR[rows,]
keywords
# Out:
#              key c                                                  repoName
# 1  visualization :                                   h2_energy-visualization
# 2           flop :                                     codedivine_maxflopscl
# 3         matrix :                                             so61pi_matrix
# 4      algorithm :                  tempredirect_groovyalgorithmsinanutshell
# 5        latency :                              belenbaas_sensorlatencytable
# 6            mkl :                                        radimklaska_apikey
# 7            mpi : vallenovasac_org.idempiere.vallenova.registromasivoseries
# 8        scaling :                                   galtay_enzo-3.0-scaling
# 9        cluster :                                       kasterma_clustering
# 10       openmpi :                                 nye_qmake-openmpi-feature
# 11          cuda :                               martinjvickers_k-means-cuda
# 12        openmp :                                 nye_qmake-openmpi-feature
# 13           gpu :                              gik0geck0_gpugraphalgorithms
# 14       runtime :                                  mdye_api_runtime_compare
# 15        vmware :                                     nmaekawa_vmware_tools
# 16        linear :                                  allenLao_linear_transfer
#                                  repo nW nFr nPu   nDe nAu  nFi  vcs      Siz
# NA                               <NA> NA  NA  NA    NA  NA   NA <NA>       NA
# 72829           codedivine_maxflopscl  1   0   0    12   2    3   hg    34602
# NA.1                             <NA> NA  NA  NA    NA  NA   NA <NA>       NA
# NA.2                             <NA> NA  NA  NA    NA  NA   NA <NA>       NA
# 42549    belenbaas_sensorlatencytable  1   0   0    18   1   14   hg    90474
# 302123             radimklaska_apikey  1   0   0     2   1    2  git    66925
# NA.3                             <NA> NA  NA  NA    NA  NA   NA <NA>       NA
# 131594        galtay_enzo-3.0-scaling  1   0   0 47641  68 5966   hg 75265238
# NA.4                             <NA> NA  NA  NA    NA  NA   NA <NA>       NA
# 273005      nye_qmake-openmpi-feature  1   0   0     3   1    2  git    58559
# 230897    martinjvickers_k-means-cuda  1   0   0     4   2    2  git   101536
# 273005.1    nye_qmake-openmpi-feature  1   0   0     3   1    2  git    58559
# NA.5                             <NA> NA  NA  NA    NA  NA   NA <NA>       NA
# 237154       mdye_api_runtime_compare  2   0   0    80   3   49  git  1574749
# 268983          nmaekawa_vmware_tools  1   0   0     0   0    0  git 60016139
# 17814        allenLao_linear_transfer  1   0   0    22   1   19  git 17707585
#                from         to              u nFl nFd
# NA               NA         NA           <NA>  NA  NA
# 72829    1369646894 1394453429     codedivine   0   0
# NA.1             NA         NA           <NA>  NA  NA
# NA.2             NA         NA           <NA>  NA  NA
# 42549    1380690770 1380690825      belenbaas   0   0
# 302123   1393365465 1393366201    radimklaska   5  14
# NA.3             NA         NA           <NA>  NA  NA
# 131594   1404359866 1404378300         galtay   0   1
# NA.4             NA         NA           <NA>  NA  NA
# 273005   1398390539 1398390866            nye   0   3
# 230897   1406470569 1406488221 martinjvickers   0   0
# 273005.1 1398390539 1398390866            nye   0   3
# NA.5             NA         NA           <NA>  NA  NA
# 237154   1404478015 1405036784           mdye   1   4
# 268983   1392426031 1392426280       nmaekawa   3   0
# 17814    1409575005 1409575550       allenLao   0   0

# %%
#read list_lib
hpc_repo2 <- read.table("list_lib",sep=' ',header=F,comment.char="",quote="")
names(hpc_repo2) <- c("key","c", "repoName")
hpc_repo2

rows2 <- c(match(hpc_repo2$repoName,prepR$repo))
lib <- prepR[rows2,]
lib
# Out:
#      key c                                  repoName
# 1 lapack :                chemoelectric_pure-lapacke
# 2   blas :      kryptick_tk-jbd-submit-mayaplayblast
# 3   fftw :                  mooviefish_fftw3_android
# 4  petsc :                              mapdes_petsc
# 5    hdf :                     psitomcat_mythen2hdf5
# 6 netcdf :               iannis_b_scc-netcdf-checker
# 7  atlas : robertmassaioli_atlassian-connect-haskell
#                                             repo nW nFr nPu nDe nAu nFi  vcs
# 65961                 chemoelectric_pure-lapacke  1   0   0   9   1   5   hg
# 206033      kryptick_tk-jbd-submit-mayaplayblast  1   0   0  20   2  16  git
# 250191                  mooviefish_fftw3_android  1   0   0  14   1  14  git
# NA                                          <NA> NA  NA  NA  NA  NA  NA <NA>
# 297490                     psitomcat_mythen2hdf5  2   0   0   2   1   2  git
# NA.1                                        <NA> NA  NA  NA  NA  NA  NA <NA>
# 314588 robertmassaioli_atlassian-connect-haskell  1   0   0  78   3  30  git
#            Siz       from         to               u nFl nFd
# 65961     6264 1316516818 1343278672   chemoelectric   3   6
# 206033  209410 1409590626 1409590626        kryptick   0   0
# 250191 1908759 1404734140 1404734140      mooviefish   0   0
# NA          NA         NA         NA            <NA>  NA  NA
# 297490   63144 1410369914 1410369994       psitomcat   4   0
# NA.1        NA         NA         NA            <NA>  NA  NA
# 314588  889521 1407141634 1410434711 robertmassaioli   8   4

# %%
#read list_pckg
hpc_repo3 <- read.table("list_pckg",sep=' ',header=F,comment.char="",quote="")
names(hpc_repo3) <- c("key","c", "repoName")
hpc_repo3

rows3 <- c(match(hpc_repo3$repoName,prepR$repo))
pckg <- prepR[rows3,]
pckg
# Out:
#         key c                                                        repoName
# 1     amber :                   wpalchemist_chamber-dashboard-events-calendar
# 2    nwchem :                                  cml_dictionary-compchem-nwchem
# 3  samtools :                                            Dreampursue_samtools
# 4    tophat : joachimjacob_galaxy-central-fixing-discordant-reporting-tophat2
# 5     stata :                                 infinit-group_instatain_android
# 6    lammps :                                                dayalsoap_lammps
# 7  espresso :                                    timurbazhirov_espresso-4.0.3
# 8       vmd :                                            svmwebdev_vmdevviper
# 9     elmer :                                      pixelmerge_pixelmerge-docs
# 10 gaussian :                                cml_dictionary-compchem-gaussian
# 11   stacks :                                        christophert_csap-stacks
# 12    petsc :                                                    mapdes_petsc
# 13 cutadapt :                           lance_parsons_cutadapt_galaxy_wrapper
# 14   octave :                                              hr_s_octavewrapper
# 15      wrf :                                                xredor_wrf2grads
# 16      sas :                                   hexarobi_ac-koa-hipchat-sassy
# 17     vasp :                                           py_project_vasphelper
# 18    maker :                                              jw-team_newsmaker2
# 19    plink :                                  stephanalber_phonegap-applinks
#                                                                   repo nW nFr
# NA                                                                <NA> NA  NA
# 71880                                   cml_dictionary-compchem-nwchem  1   0
# 103343                                            Dreampursue_samtools  1   0
# 180850 joachimjacob_galaxy-central-fixing-discordant-reporting-tophat2  1   0
# 161046                                 infinit-group_instatain_android  1   0
# NA.1                                                              <NA> NA  NA
# 369814                                    timurbazhirov_espresso-4.0.3  1   0
# 356527                                            svmwebdev_vmdevviper  2   0
# 290285                                      pixelmerge_pixelmerge-docs  2   0
# 71879                                 cml_dictionary-compchem-gaussian  1   0
# 68410                                         christophert_csap-stacks  1   0
# NA.2                                                              <NA> NA  NA
# 209535                           lance_parsons_cutadapt_galaxy_wrapper  2   0
# 154138                                              hr_s_octavewrapper  1   0
# 404996                                                xredor_wrf2grads  1   0
# NA.3                                                              <NA> NA  NA
# 299511                                           py_project_vasphelper  1   0
# 191110                                              jw-team_newsmaker2  2   0
# 351416                                  stephanalber_phonegap-applinks  1   0
#        nPu   nDe nAu   nFi  vcs       Siz       from         to             u
# NA      NA    NA  NA    NA <NA>        NA         NA         NA          <NA>
# 71880    0     3   3     1   hg      6519 1329709061 1329838327           cml
# 103343   0  2026  11   191  git   4842395 1393866103 1393866104   Dreampursue
# 180850   0 38462  75  6882   hg 141647512 1360675993 1360677355  joachimjacob
# 161046   0     0   0     0  git       697 1369838946 1371777452 infinit-group
# NA.1    NA    NA  NA    NA <NA>        NA         NA         NA          <NA>
# 369814   0  4843   2  4843  git  44483891 1405669733 1405669733 timurbazhirov
# 356527   0   228   1   228   hg   2855728 1386215370 1386218017     svmwebdev
# 290285   0    44   1    30  git     28930 1345414423 1346432366    pixelmerge
# 71879    0     2   2     1   hg     11964 1329709022 1329742675           cml
# 68410    0    26   1    16  git    314415 1395946041 1395954941  christophert
# NA.2    NA    NA  NA    NA <NA>        NA         NA         NA          <NA>
# 209535   0    38   1    14   hg     53369 1411088961 1411507344 lance_parsons
# 154138   0     0   0     0  git     33348 1410144784 1410144815          hr_s
# 404996   0    27   1    25   hg     78570 1380138737 1380138947        xredor
# NA.3    NA    NA  NA    NA <NA>        NA         NA         NA          <NA>
# 299511   0 11317   1 11317   hg  12350579 1271064666 1340683589    py_project
# 191110   0    36   2    20  git   5794086 1409333911 1410436411       jw-team
# 351416   0     7   1     4  git    121489 1408755178 1408761980  stephanalber
#        nFl nFd
# NA      NA  NA
# 71880    4   0
# 103343   1   1
# 180850   0   0
# 161046   1   0
# NA.1    NA  NA
# 369814   0   0
# 356527   3   0
# 290285   0   0
# 71879    4   0
# 68410    0   0
# NA.2    NA  NA
# 209535   2   9
# 154138   0   0
# 404996   1   2
# NA.3    NA  NA
# 299511   0   0
# 191110   0   0
# 351416   0   0

# %%
rbind(keywords,lib,pckg)
# Out:
#                                                                     repo nW nFr
# NA                                                                  <NA> NA  NA
# 72829                                              codedivine_maxflopscl  1   0
# NA.1                                                                <NA> NA  NA
# NA.2                                                                <NA> NA  NA
# 42549                                       belenbaas_sensorlatencytable  1   0
# 302123                                                radimklaska_apikey  1   0
# NA.3                                                                <NA> NA  NA
# 131594                                           galtay_enzo-3.0-scaling  1   0
# NA.4                                                                <NA> NA  NA
# 273005                                         nye_qmake-openmpi-feature  1   0
# 230897                                       martinjvickers_k-means-cuda  1   0
# 273005.1                                       nye_qmake-openmpi-feature  1   0
# NA.5                                                                <NA> NA  NA
# 237154                                          mdye_api_runtime_compare  2   0
# 268983                                             nmaekawa_vmware_tools  1   0
# 17814                                           allenLao_linear_transfer  1   0
# 65961                                         chemoelectric_pure-lapacke  1   0
# 206033                              kryptick_tk-jbd-submit-mayaplayblast  1   0
# 250191                                          mooviefish_fftw3_android  1   0
# NA1                                                                 <NA> NA  NA
# 297490                                             psitomcat_mythen2hdf5  2   0
# NA.11                                                               <NA> NA  NA
# 314588                         robertmassaioli_atlassian-connect-haskell  1   0
# NA2                                                                 <NA> NA  NA
# 71880                                     cml_dictionary-compchem-nwchem  1   0
# 103343                                              Dreampursue_samtools  1   0
# 180850   joachimjacob_galaxy-central-fixing-discordant-reporting-tophat2  1   0
# 161046                                   infinit-group_instatain_android  1   0
# NA.12                                                               <NA> NA  NA
# 369814                                      timurbazhirov_espresso-4.0.3  1   0
# 356527                                              svmwebdev_vmdevviper  2   0
# 290285                                        pixelmerge_pixelmerge-docs  2   0
# 71879                                   cml_dictionary-compchem-gaussian  1   0
# 68410                                           christophert_csap-stacks  1   0
# NA.21                                                               <NA> NA  NA
# 209535                             lance_parsons_cutadapt_galaxy_wrapper  2   0
# 154138                                                hr_s_octavewrapper  1   0
# 404996                                                  xredor_wrf2grads  1   0
# NA.31                                                               <NA> NA  NA
# 299511                                             py_project_vasphelper  1   0
# 191110                                                jw-team_newsmaker2  2   0
# 351416                                    stephanalber_phonegap-applinks  1   0
#          nPu   nDe nAu   nFi  vcs       Siz       from         to
# NA        NA    NA  NA    NA <NA>        NA         NA         NA
# 72829      0    12   2     3   hg     34602 1369646894 1394453429
# NA.1      NA    NA  NA    NA <NA>        NA         NA         NA
# NA.2      NA    NA  NA    NA <NA>        NA         NA         NA
# 42549      0    18   1    14   hg     90474 1380690770 1380690825
# 302123     0     2   1     2  git     66925 1393365465 1393366201
# NA.3      NA    NA  NA    NA <NA>        NA         NA         NA
# 131594     0 47641  68  5966   hg  75265238 1404359866 1404378300
# NA.4      NA    NA  NA    NA <NA>        NA         NA         NA
# 273005     0     3   1     2  git     58559 1398390539 1398390866
# 230897     0     4   2     2  git    101536 1406470569 1406488221
# 273005.1   0     3   1     2  git     58559 1398390539 1398390866
# NA.5      NA    NA  NA    NA <NA>        NA         NA         NA
# 237154     0    80   3    49  git   1574749 1404478015 1405036784
# 268983     0     0   0     0  git  60016139 1392426031 1392426280
# 17814      0    22   1    19  git  17707585 1409575005 1409575550
# 65961      0     9   1     5   hg      6264 1316516818 1343278672
# 206033     0    20   2    16  git    209410 1409590626 1409590626
# 250191     0    14   1    14  git   1908759 1404734140 1404734140
# NA1       NA    NA  NA    NA <NA>        NA         NA         NA
# 297490     0     2   1     2  git     63144 1410369914 1410369994
# NA.11     NA    NA  NA    NA <NA>        NA         NA         NA
# 314588     0    78   3    30  git    889521 1407141634 1410434711
# NA2       NA    NA  NA    NA <NA>        NA         NA         NA
# 71880      0     3   3     1   hg      6519 1329709061 1329838327
# 103343     0  2026  11   191  git   4842395 1393866103 1393866104
# 180850     0 38462  75  6882   hg 141647512 1360675993 1360677355
# 161046     0     0   0     0  git       697 1369838946 1371777452
# NA.12     NA    NA  NA    NA <NA>        NA         NA         NA
# 369814     0  4843   2  4843  git  44483891 1405669733 1405669733
# 356527     0   228   1   228   hg   2855728 1386215370 1386218017
# 290285     0    44   1    30  git     28930 1345414423 1346432366
# 71879      0     2   2     1   hg     11964 1329709022 1329742675
# 68410      0    26   1    16  git    314415 1395946041 1395954941
# NA.21     NA    NA  NA    NA <NA>        NA         NA         NA
# 209535     0    38   1    14   hg     53369 1411088961 1411507344
# 154138     0     0   0     0  git     33348 1410144784 1410144815
# 404996     0    27   1    25   hg     78570 1380138737 1380138947
# NA.31     NA    NA  NA    NA <NA>        NA         NA         NA
# 299511     0 11317   1 11317   hg  12350579 1271064666 1340683589
# 191110     0    36   2    20  git   5794086 1409333911 1410436411
# 351416     0     7   1     4  git    121489 1408755178 1408761980
#                        u nFl nFd
# NA                  <NA>  NA  NA
# 72829         codedivine   0   0
# NA.1                <NA>  NA  NA
# NA.2                <NA>  NA  NA
# 42549          belenbaas   0   0
# 302123       radimklaska   5  14
# NA.3                <NA>  NA  NA
# 131594            galtay   0   1
# NA.4                <NA>  NA  NA
# 273005               nye   0   3
# 230897    martinjvickers   0   0
# 273005.1             nye   0   3
# NA.5                <NA>  NA  NA
# 237154              mdye   1   4
# 268983          nmaekawa   3   0
# 17814           allenLao   0   0
# 65961      chemoelectric   3   6
# 206033          kryptick   0   0
# 250191        mooviefish   0   0
# NA1                 <NA>  NA  NA
# 297490         psitomcat   4   0
# NA.11               <NA>  NA  NA
# 314588   robertmassaioli   8   4
# NA2                 <NA>  NA  NA
# 71880                cml   4   0
# 103343       Dreampursue   1   1
# 180850      joachimjacob   0   0
# 161046     infinit-group   1   0
# NA.12               <NA>  NA  NA
# 369814     timurbazhirov   0   0
# 356527         svmwebdev   3   0
# 290285        pixelmerge   0   0
# 71879                cml   4   0
# 68410       christophert   0   0
# NA.21               <NA>  NA  NA
# 209535     lance_parsons   2   9
# 154138              hr_s   0   0
# 404996            xredor   1   2
# NA.31               <NA>  NA  NA
# 299511        py_project   0   0
# 191110           jw-team   0   0
# 351416      stephanalber   0   0
